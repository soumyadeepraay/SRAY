# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **SOUMYADEEP RAY**
# DATA SCIENTIST

# %% [markdown]
# _I am interested in data science because i love working with and analysing data ,data is the ultimate truth of anything._

# %% [markdown]
# ### I am adding two integers in cell 5

# %%
a=(10+11)
print(a)
# Out:
# 21

# %% [markdown]
# 1.![image of a cat sitting on a chair](https://assets3.thrillist.com/v1/image/2560276/1584x912/scale;webp=auto;jpeg_quality=60;progressive.jpg)
#
# 2.https://https://in.coursera.org/
#
# 3.~THIS AN EXAMPLE OF STRIKETHROUGH~
